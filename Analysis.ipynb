# %%
import pandas as pd
import numpy as np
import html
import lxml.etree as etree
from matplotlib import pyplot as plt
from collections import defaultdict

# %% [markdown]
# # Reading Data

# %%
# dataset_addr = "sample.xml"
dataset_addr = "dblp.xml"

# %%
parser = etree.XMLParser(recover=True)

# %%
tree = etree.parse(dataset_addr, parser=parser)

# %% [markdown]
# # Schema

# %%
s = set()
for n in tree.getroot():
    for a in n:
        s.add(a.tag)

# %%
s
# Out:
# {<cyfunction Entity at 0x11142ff50>,
#  'address',
#  'author',
#  'booktitle',
#  'cdrom',
#  'chapter',
#  'cite',
#  'crossref',
#  'editor',
#  'ee',
#  'isbn',
#  'journal',
#  'month',
#  'note',
#  'number',
#  'pages',
#  'publisher',
#  'school',
#  'series',
#  'title',
#  'url',
#  'volume',
#  'year'}

# %%
len(tree.getroot())
# Out:
# 7256826

# %%
t = set()
for n in tree.getroot():
    t.add(n.tag)

# %%
t
# Out:
# {'article',
#  'book',
#  'incollection',
#  'inproceedings',
#  'mastersthesis',
#  'phdthesis',
#  'proceedings',
#  'www'}

# %%
u = defaultdict(set)
for n in tree.getroot():
    for a in n:
        u[n.tag].add(a.tag)

# %%
u
# Out:
# defaultdict(set,
#             {'phdthesis': {'author',
#               'ee',
#               'isbn',
#               'month',
#               'note',
#               'number',
#               'pages',
#               'publisher',
#               'school',
#               'series',
#               'title',
#               'url',
#               'volume',
#               'year'},
#              'book': {<cyfunction Entity at 0x11142ff50>,
#               'author',
#               'booktitle',
#               'cdrom',
#               'cite',
#               'crossref',
#               'editor',
#               'ee',
#               'isbn',
#               'month',
#               'note',
#               'pages',
#               'publisher',
#               'school',
#               'series',
#               'title',
#               'url',
#               'volume',
#               'year'},
#              'mastersthesis': {'author',
#               'ee',
#               'note',
#               'school',
#               'title',
#               'year'},
#              'incollection': {'author',
#               'booktitle',
#               'cdrom',
#               'chapter',
#               'cite',
#               'crossref',
#               'ee',
#               'note',
#               'number',
#               'pages',
#               'publisher',
#               'title',
#               'url',
#               'year'},
#              'inproceedings': {<cyfunction Entity at 0x11142ff50>,
#               'author',
#               'booktitle',
#               'cdrom',
#               'cite',
#               'crossref',
#               'editor',
#               'ee',
#               'month',
#               'note',
#               'number',
#               'pages',
#               'title',
#               'url',
#               'year'},
#              'proceedings': {'address',
#               'author',
#               'booktitle',
#               'cite',
#               'editor',
#               'ee',
#               'isbn',
#               'journal',
#               'note',
#               'number',
#               'pages',
#               'publisher',
#               'series',
#               'title',
#               'url',
#               'volume',
#               'year'},
#              'article': {<cyfunction Entity at 0x11142ff50>,
#               'author',
#               'booktitle',
#               'cdrom',
#               'cite',
#               'crossref',
#               'editor',
#               'ee',
#               'journal',
#               'month',
#               'note',
#               'number',
#               'pages',
#               'publisher',
#               'title',
#               'url',
#               'volume',
#               'year'},
#              'www': {<cyfunction Entity at 0x11142ff50>,
#               'author',
#               'cite',
#               'crossref',
#               'editor',
#               'ee',
#               'note',
#               'title',
#               'url',
#               'year'}})

# %% [markdown]
# # Creating Dataframe

# %%
rows = []
for node in tree.getroot():
    if node.tag in ["inproceedings", "article"]:
        year = node.find("year")
        if year != None:
            year = year.text
        rows.append({
            "title": node.find("title").text,
            "authors": [author.text for author in node.findall("author")],
            "year": year,
            "type": node.tag,
        })

# %%
len(rows)
# Out:
# 4658518

# %%
df = pd.DataFrame(rows)

# %%
df
# Out:
#                                                      title  \
# 0                      Generative Artificial Intelligence.
# 1           Practical Introspection as Inspiration for AI.
# 2        'Quantum Linguistics' and Searle's Chinese Roo...
# 3                    Feasibility of Whole Brain Emulation.
# 4        The New Experimental Science of Physical Cogni...
# ...                                                    ...
# 4658513  Interactive Support for Non-Programmers: The R...
# 4658514  Common Subexpression Identification in General...
# 4658515  Catchment classification by runoff behaviour w...
# 4658516  Relational Completeness of Data Base Sublangua...
# 4658517  Analysis of projected hydrological behavior of...
#
#                                                    authors  year  \
# 0        [Tijn van der Zant, Matthijs Kouw, Lambert Sch...  2011
# 1                                              [Sam Freed]  2011
# 2        [John Mark Bishop, Slawomir J. Nasuto, Bob Coe...  2011
# 3                                        [Anders Sandberg]  2011
# 4                                      [Fabio Bonsignorio]  2011
# ...                                                    ...   ...
# 4658513                           [E. F. Codd, C. J. Date]  1974
# 4658514                               [Patrick A. V. Hall]  1974
# 4658515  [Rita Ley, Markus Casper, Hugo Hellebrand, Ral...  2011
# 4658516                                       [E. F. Codd]  1972
# 4658517  [Markus Casper, Gayane Grigoryan, Oliver Gronz...  2012
#
#                   type
# 0        inproceedings
# 1        inproceedings
# 2        inproceedings
# 3        inproceedings
# 4        inproceedings
# ...                ...
# 4658513        article
# 4658514        article
# 4658515        article
# 4658516        article
# 4658517        article
#
# [4658518 rows x 4 columns]

# %%
df["num_of_authors"] = df["authors"].map(lambda x: len(x))

# %% [markdown]
# # Cleaning up Data

# %%
df[df["num_of_authors"] == 0]
# Out:
#                                                      title authors  year  \
# 57                                                 (error)      []  None
# 58                                   (was never published)      []  None
# 59                                                       …      []  None
# 72       The 1995 SQL Reunion: People, Project, and Pol...      []  1997
# 315                                          18. Workshop       []  1992
# ...                                                    ...     ...   ...
# 4653253   Continuous monitoring and the status quo effect.      []  2010
# 4653397  Review of: "Comparisons of three different met...      []  2010
# 4654840                                The Next Killer Ap.      []  2006
# 4655078  Human-Computer Interaction in Radiotherapy Tar...      []  2011
# 4655571                  Professor Toader Jucan at Age 60.      []  2001
#
#             type  num_of_authors
# 57       article               0
# 58       article               0
# 59       article               0
# 72       article               0
# 315      article               0
# ...          ...             ...
# 4653253  article               0
# 4653397  article               0
# 4654840  article               0
# 4655078  article               0
# 4655571  article               0
#
# [15861 rows x 5 columns]

# %%
df[df["year"].map(lambda x: x == None or len(x) != 4)]
# Out:
#                     title authors  year     type  num_of_authors
# 57                (error)      []  None  article               0
# 58  (was never published)      []  None  article               0
# 59                      …      []  None  article               0

# %%
df[df["title"] == None]
# Out:
# Empty DataFrame
# Columns: [title, authors, year, type, num_of_authors]
# Index: []

# %%
df[df["title"].map(lambda x: type(x) != str)]
# Out:
#         title                                            authors  year  \
# 420      None                                       [Jutta Krei]  1991
# 585      None                                         [Noam Paz]  1989
# 594      None                                [Carola Eschenbach]  1988
# 7149     None  [Kaori Kobayashi, Daisuke Kitayama, Kazutoshi ...  2011
# 7201     None                    [Junjun Yin, James D. Carswell]  2011
# ...       ...                                                ...   ...
# 4653218  None      [Steve G. Sutton, Matthew Holt, Vicky Arnold]  2016
# 4655855  None  [Ladislav Marsik, Petr Martisek, Jaroslav Poko...  2018
# 4655968  None  [Mira Kim, Shao-Ting Wang, David A. Ostrowski,...  2016
# 4656015  None  [Shao-Ting Wang, Jennifer Jin, Pete Rivett, At...  2015
# 4656133  None  [Uraz Yavanoglu, Taha Yasin Ibisoglu, Setra Ge...  2018
#
#                   type  num_of_authors
# 420            article               1
# 585            article               1
# 594            article               1
# 7149     inproceedings               3
# 7201     inproceedings               2
# ...                ...             ...
# 4653218        article               3
# 4655855        article               9
# 4655968        article               5
# 4656015        article               4
# 4656133        article               3
#
# [5563 rows x 5 columns]

# %%
df = df[df["year"].map(lambda x: x != None and len(x) == 4)]

# %%
df = df[df["num_of_authors"] > 0]

# %%
df = df[df["title"] != None]

# %%
df = df[df["title"].map(lambda x: type(x) == str)]

# %%
df
# Out:
#                                                      title  \
# 0                      Generative Artificial Intelligence.
# 1           Practical Introspection as Inspiration for AI.
# 2        'Quantum Linguistics' and Searle's Chinese Roo...
# 3                    Feasibility of Whole Brain Emulation.
# 4        The New Experimental Science of Physical Cogni...
# ...                                                    ...
# 4658513  Interactive Support for Non-Programmers: The R...
# 4658514  Common Subexpression Identification in General...
# 4658515  Catchment classification by runoff behaviour w...
# 4658516  Relational Completeness of Data Base Sublangua...
# 4658517  Analysis of projected hydrological behavior of...
#
#                                                    authors  year  \
# 0        [Tijn van der Zant, Matthijs Kouw, Lambert Sch...  2011
# 1                                              [Sam Freed]  2011
# 2        [John Mark Bishop, Slawomir J. Nasuto, Bob Coe...  2011
# 3                                        [Anders Sandberg]  2011
# 4                                      [Fabio Bonsignorio]  2011
# ...                                                    ...   ...
# 4658513                           [E. F. Codd, C. J. Date]  1974
# 4658514                               [Patrick A. V. Hall]  1974
# 4658515  [Rita Ley, Markus Casper, Hugo Hellebrand, Ral...  2011
# 4658516                                       [E. F. Codd]  1972
# 4658517  [Markus Casper, Gayane Grigoryan, Oliver Gronz...  2012
#
#                   type  num_of_authors
# 0        inproceedings               3
# 1        inproceedings               1
# 2        inproceedings               3
# 3        inproceedings               1
# 4        inproceedings               1
# ...                ...             ...
# 4658513        article               2
# 4658514        article               1
# 4658515        article               4
# 4658516        article               1
# 4658517        article               7
#
# [4637178 rows x 5 columns]

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Over the Years

# %%
by_size = df.groupby("year").size()
by_size
# Out:
# year
# 1936        12
# 1937        14
# 1938        10
# 1939        18
# 1940        10
#          ...
# 2016    288819
# 2017    307978
# 2018    334850
# 2019    285674
# 2020      2016
# Length: 85, dtype: int64

# %%
ax = by_size.plot(figsize=(16, 9))
ax.set_title("Number of Articls per Year")
ax.set_xlabel("Year")
ax.set_ylabel("Article")
ax.grid()

# %%
ax = by_size.plot(figsize=(16, 9))
ax.set_title("Number of Articls per Year")
ax.set_xlabel("Year")
ax.set_ylabel("Article")
ax.set_yscale("log")
ax.grid()

# %% [markdown]
# ## Number of Authors

# %%
num_of_authors_by_size = df.groupby("num_of_authors").size()
num_of_authors_by_size
# Out:
# num_of_authors
# 1       714332
# 2      1274897
# 3      1175080
# 4       744588
# 5       376397
#         ...
# 119          1
# 139          1
# 155          1
# 264          1
# 287          2
# Length: 95, dtype: int64

# %%
df[df["num_of_authors"] >= 100]
# Out:
#                                                      title  \
# 209592        An overview of the BlueGene/L Supercomputer.
# 537546   The Grid2003 Production Grid: Principles and P...
# 1136073  The Visual Object Tracking VOT2017 Challenge R...
# 1207826  VisDrone-DET2018: The Vision Meets Drone Objec...
# 1209157  The Sixth Visual Object Tracking VOT2018 Chall...
# 1211193  The Visual Object Tracking VOT2016 Challenge R...
# 2620455  Length Sensing and Control in the Virgo Gravit...
# 3026411  The IceProd framework: Distributed data proces...
# 3258430       A promoter-level mammalian expression atlas.
# 3360828  Finding needles in haystacks: linking scientif...
# 3505081  The BioMart community portal: an innovative al...
# 4194402  Theano: A Python framework for fast computatio...
# 4247583  Machine Learning in High Energy Physics Commun...
# 4260066  The IceProd Framework: Distributed Data Proces...
#
#                                                    authors  year  \
# 209592   [Narasimha R. Adiga, George Alm, George S. Alm...  2002
# 537546   [Ian T. Foster, Jerry Gieraltowski, Scott Gose...  2004
# 1136073  [Matej Kristan, Ales Leonardis, Jiri Matas, Mi...  2017
# 1207826  [Pengfei Zhu, Longyin Wen, Dawei Du, Xiao Bian...  2018
# 1209157  [Matej Kristan, Ales Leonardis, Jiri Matas, Mi...  2018
# 1211193  [Matej Kristan, Ales Leonardis, Jiri Matas, Mi...  2016
# 2620455  [Fausto Acernese, P. Amico, M. Al-Shourbagy, S...  2006
# 3026411  [Mark G. Aartsen, Rasha U. Abbasi, Markus Acke...  2015
# 3258430  [The Fantom Consortium, RIKEN PMII, RIKEN CLST...  2014
# 3360828  [Conrad L. Schoch, Barbara Robbertse, Vincent ...  2014
# 3505081  [Damian Smedley, Syed Haider, Steffen Durinck,...  2015
# 4194402  [Rami Al-Rfou', Guillaume Alain, Amjad Almahai...  2016
# 4247583  [Kim Albertsson, Piero Altoe, Dustin Anderson,...  2018
# 4260066  [Mark G. Aartsen, Rasha U. Abbasi, Markus Acke...  2013
#
#                   type  num_of_authors
# 209592   inproceedings             115
# 537546   inproceedings             102
# 1136073  inproceedings             104
# 1207826  inproceedings             105
# 1209157  inproceedings             155
# 1211193  inproceedings             139
# 2620455        article             119
# 3026411        article             287
# 3258430        article             264
# 3360828        article             101
# 3505081        article             105
# 4194402        article             112
# 4247583        article             118
# 4260066        article             287

# %%
ax = num_of_authors_by_size.plot.bar(figsize=(25, 10))
ax.set_title("Number of Authors of Articls\nfrom 1936 until 2020")
ax.set_xlabel("Number of Authors")
ax.set_ylabel("Number of Articles")
ax.grid()

# %%
ax = num_of_authors_by_size.plot.bar(figsize=(25, 10))
ax.set_title("Number of Authors of Articls\nfrom 1936 until 2020")
ax.set_xlabel("Number of Authors")
ax.set_ylabel("Number of Articles")
ax.set_yscale("log")
ax.grid()

# %%
num_of_authors_by_size[num_of_authors_by_size >= 100]
# Out:
# num_of_authors
# 1      714332
# 2     1274897
# 3     1175080
# 4      744588
# 5      376397
# 6      179106
# 7       77914
# 8       39260
# 9       20513
# 10      12001
# 11       6846
# 12       4395
# 13       2961
# 14       2007
# 15       1424
# 16        990
# 17        787
# 18        613
# 19        498
# 20        405
# 21        320
# 22        239
# 23        199
# 24        181
# 25        151
# 26        101
# 27        110
# 28        112
# dtype: int64

# %%
ax = num_of_authors_by_size[num_of_authors_by_size > 10000].plot.bar(figsize=(15, 10))
ax.set_title("Number of Authors of Articls\nfrom 1936 until 2020\n(Only Values >= 10000)")
ax.set_xlabel("Number of Authors")
ax.set_ylabel("Number of Articles")
ax.grid()

# %% [markdown]
# ## Number of Authors over the Years

# %%
by_year_number_of_authors = df.groupby(["year", "num_of_authors"]).size()
by_year_number_of_authors
# Out:
# year  num_of_authors
# 1936  1                 12
# 1937  1                 14
# 1938  1                  9
#       2                  1
# 1939  1                 18
#                         ..
# 2020  7                 47
#       8                 18
#       9                  2
#       10                 1
#       11                 2
# Length: 1492, dtype: int64

# %%
ax = by_year_number_of_authors[by_year_number_of_authors > 1000].unstack("num_of_authors").plot(figsize=(16, 9))
ax.set_title("Number of Authors of Articls per Year\n(Only Values >= 10000)")
ax.set_xlabel("Year")
ax.set_ylabel("Number of Articles")
ax.grid()
ax.legend(title="Number of Authors")

# %%
by_year_number_of_authors[by_year_number_of_authors > 10000]
# Out:
# year  num_of_authors
# 1991  1                 10180
# 1992  1                 10786
#       2                 10748
# 1993  1                 12081
#       2                 13732
#                         ...
# 2019  2                 56797
#       3                 70300
#       4                 57586
#       5                 37434
#       6                 21692
# Length: 118, dtype: int64

# %%
by_year_number_of_authors.unstack("num_of_authors")
# Out:
# num_of_authors      1        2        3        4        5        6       7    \
# year
# 1936               12.0      NaN      NaN      NaN      NaN      NaN     NaN
# 1937               14.0      NaN      NaN      NaN      NaN      NaN     NaN
# 1938                9.0      1.0      NaN      NaN      NaN      NaN     NaN
# 1939               18.0      NaN      NaN      NaN      NaN      NaN     NaN
# 1940                8.0      2.0      NaN      NaN      NaN      NaN     NaN
# ...                 ...      ...      ...      ...      ...      ...     ...
# 2016            26187.0  66246.0  76611.0  57095.0  32104.0  15680.0  6809.0
# 2017            26132.0  68124.0  80173.0  61961.0  36105.0  18210.0  7907.0
# 2018            25885.0  70280.0  85203.0  67791.0  41678.0  22394.0  9936.0
# 2019            20708.0  56797.0  70300.0  57586.0  37434.0  21692.0  9630.0
# 2020              143.0    461.0    572.0    404.0    252.0    114.0    47.0
#
# num_of_authors     8       9       10   ...  104  105  112  115  118  119  \
# year                                    ...
# 1936               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1937               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1938               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1939               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1940               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# ...                ...     ...     ...  ...  ...  ...  ...  ...  ...  ...
# 2016            3380.0  1733.0   965.0  ...  NaN  NaN  1.0  NaN  NaN  NaN
# 2017            4027.0  1959.0  1179.0  ...  1.0  NaN  NaN  NaN  NaN  NaN
# 2018            4973.0  2568.0  1440.0  ...  NaN  1.0  NaN  NaN  1.0  NaN
# 2019            4846.0  2560.0  1424.0  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 2020              18.0     2.0     1.0  ...  NaN  NaN  NaN  NaN  NaN  NaN
#
# num_of_authors  139  155  264  287
# year
# 1936            NaN  NaN  NaN  NaN
# 1937            NaN  NaN  NaN  NaN
# 1938            NaN  NaN  NaN  NaN
# 1939            NaN  NaN  NaN  NaN
# 1940            NaN  NaN  NaN  NaN
# ...             ...  ...  ...  ...
# 2016            1.0  NaN  NaN  NaN
# 2017            NaN  NaN  NaN  NaN
# 2018            NaN  1.0  NaN  NaN
# 2019            NaN  NaN  NaN  NaN
# 2020            NaN  NaN  NaN  NaN
#
# [85 rows x 95 columns]

# %%
by_year_number_of_authors_percentage = by_year_number_of_authors.groupby("year").apply(lambda x: 100 * x / x.sum())
by_year_number_of_authors_percentage[by_year_number_of_authors_percentage > 0.5]
# Out:
# year  num_of_authors
# 1936  1                 100.000000
# 1937  1                 100.000000
# 1938  1                  90.000000
#       2                  10.000000
# 1939  1                 100.000000
#                            ...
# 2020  4                  20.039683
#       5                  12.500000
#       6                   5.654762
#       7                   2.331349
#       8                   0.892857
# Length: 435, dtype: float64

# %%
ax = by_year_number_of_authors_percentage[by_year_number_of_authors_percentage > 0.5].unstack("num_of_authors").plot(figsize=(16, 9))
ax.set_title("Distribution of Number of Authors of Articls per Year\n(Only Values >= 0.5%)")
ax.set_xlabel("Year")
ax.set_ylabel("Percentage of All Articles of Year")
ax.grid()
ax.legend(title="Number of Authors")

# %% [markdown]
# ## By Author

# %%
by_each_author = pd.DataFrame(df["authors"].tolist(), index=df["title"]).stack().reset_index(level=1, drop=True).reset_index(name="authors").rename(columns={"authors": "author"})
by_each_author = by_each_author.set_index("title").join(df.set_index("title")).reset_index()
by_each_author

# %%
# tmp = df[:1000]
# res = pd.DataFrame(tmp["authors"].tolist(), index=tmp["title"]).stack().reset_index(level=1, drop=True).reset_index(name="authors").rename(columns={"authors": "author"})
# res = res.set_index("title").join(tmp.set_index("title")).reset_index()
# res
# Out:
#                                                   title                author  \
# 0              "Computational Ontology and Deontology".   Raffaela Giovagnoli
# 1                                            "Der Film   Stefan J. Schierholz
# 2     "Dictionary Dialog" - Entwurf des Funktionsumf...          Anja Theuner
# 3     'Quantum Linguistics' and Searle's Chinese Roo...      John Mark Bishop
# 4     'Quantum Linguistics' and Searle's Chinese Roo...    Slawomir J. Nasuto
# ...                                                 ...                   ...
# 1953  eSPERTo's Paraphrastic Knowledge Applied to Qu...                    Lu
# 1954     tele-TASK - Teleteaching Anywhere Solution Kit      Christoph Meinel
# 1955     tele-TASK - Teleteaching Anywhere Solution Kit     Volker Schillings
# 1956          tele-TASK - Teleteaching praxistauglich f      Christoph Meinel
# 1957          tele-TASK - Teleteaching praxistauglich f     Volker Schillings
#
#                                                 authors  year           type  \
# 0                                 [Raffaela Giovagnoli]  2011  inproceedings
# 1                                [Stefan J. Schierholz]  1992        article
# 2                                        [Anja Theuner]  1992        article
# 3     [John Mark Bishop, Slawomir J. Nasuto, Bob Coe...  2011  inproceedings
# 4     [John Mark Bishop, Slawomir J. Nasuto, Bob Coe...  2011  inproceedings
# ...                                                 ...   ...            ...
# 1953  [Cristina Mota, Anabela Barreiro, Francisco Ra...  2016  inproceedings
# 1954              [Christoph Meinel, Volker Schillings]  2002        article
# 1955              [Christoph Meinel, Volker Schillings]  2002        article
# 1956              [Christoph Meinel, Volker Schillings]  2003        article
# 1957              [Christoph Meinel, Volker Schillings]  2003        article
#
#       num_of_authors
# 0                  1
# 1                  1
# 2                  1
# 3                  3
# 4                  3
# ...              ...
# 1953               6
# 1954               2
# 1955               2
# 1956               2
# 1957               2
#
# [1958 rows x 6 columns]

# %%
by_each_author_year = res.groupby(["author", "year"]).size()
by_each_author_year
