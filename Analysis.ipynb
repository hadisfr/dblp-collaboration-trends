# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from collections import defaultdict

# %% [markdown]
# # Load Dataset

# %%
pd_addr = "articles.pkl"

# %%
df = pd.read_pickle(pd_addr)

# %%
df
# Out:
#                                                      title  \
# 0                      Generative Artificial Intelligence.
# 1           Practical Introspection as Inspiration for AI.
# 2        'Quantum Linguistics' and Searle's Chinese Roo...
# 3                    Feasibility of Whole Brain Emulation.
# 4        The New Experimental Science of Physical Cogni...
# ...                                                    ...
# 4667234  Interactive Support for Non-Programmers: The R...
# 4667235  Common Subexpression Identification in General...
# 4667236  Catchment classification by runoff behaviour w...
# 4667237  Relational Completeness of Data Base Sublangua...
# 4667238  Analysis of projected hydrological behavior of...
#
#                                                    authors  year  \
# 0        [Tijn van der Zant, Matthijs Kouw, Lambert Sch...  2011
# 1                                              [Sam Freed]  2011
# 2        [John Mark Bishop, Slawomir J. Nasuto, Bob Coe...  2011
# 3                                        [Anders Sandberg]  2011
# 4                                      [Fabio Bonsignorio]  2011
# ...                                                    ...   ...
# 4667234                           [E. F. Codd, C. J. Date]  1974
# 4667235                               [Patrick A. V. Hall]  1974
# 4667236  [Rita Ley, Markus Casper, Hugo Hellebrand, Ral...  2011
# 4667237                                       [E. F. Codd]  1972
# 4667238  [Markus Casper, Gayane Grigoryan, Oliver Gronz...  2012
#
#                   type  num_of_authors
# 0        inproceedings               3
# 1        inproceedings               1
# 2        inproceedings               3
# 3        inproceedings               1
# 4        inproceedings               1
# ...                ...             ...
# 4667234        article               2
# 4667235        article               1
# 4667236        article               4
# 4667237        article               1
# 4667238        article               7
#
# [4645875 rows x 5 columns]

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Over the Years

# %%
by_size = df.groupby("year").size()
by_size
# Out:
# year
# 1936        12
# 1937        14
# 1938        10
# 1939        18
# 1940        10
#          ...
# 2016    288795
# 2017    307977
# 2018    335049
# 2019    293650
# 2020      2339
# Length: 85, dtype: int64

# %%
ax = by_size.plot(figsize=(16, 9))
ax.set_title("Number of Articls per Year")
ax.set_xlabel("Year")
ax.set_ylabel("Article")
ax.grid()

# %%
ax = by_size.plot(figsize=(16, 9))
ax.set_title("Number of Articls per Year")
ax.set_xlabel("Year")
ax.set_ylabel("Article")
ax.set_yscale("log")
ax.grid()

# %% [markdown]
# ## Number of Authors

# %%
num_of_authors_by_size = df.groupby("num_of_authors").size()
num_of_authors_by_size
# Out:
# num_of_authors
# 1       714996
# 2      1276772
# 3      1177290
# 4       746326
# 5       377497
#         ...
# 119          1
# 139          1
# 155          1
# 264          1
# 287          2
# Length: 95, dtype: int64

# %%
df[df["num_of_authors"] >= 100]
# Out:
#                                                      title  \
# 210012        An overview of the BlueGene/L Supercomputer.
# 538488   The Grid2003 Production Grid: Principles and P...
# 1137966  The Visual Object Tracking VOT2017 Challenge R...
# 1209719  VisDrone-DET2018: The Vision Meets Drone Objec...
# 1211050  The Sixth Visual Object Tracking VOT2018 Chall...
# 1213086  The Visual Object Tracking VOT2016 Challenge R...
# 2625699  Length Sensing and Control in the Virgo Gravit...
# 3032755  The IceProd framework: Distributed data proces...
# 3264918       A promoter-level mammalian expression atlas.
# 3367833  Finding needles in haystacks: linking scientif...
# 3512319  The BioMart community portal: an innovative al...
# 4202317  Theano: A Python framework for fast computatio...
# 4255557  Machine Learning in High Energy Physics Commun...
# 4268065  The IceProd Framework: Distributed Data Proces...
#
#                                                    authors  year  \
# 210012   [Narasimha R. Adiga, George Alm, George S. Alm...  2002
# 538488   [Ian T. Foster, Jerry Gieraltowski, Scott Gose...  2004
# 1137966  [Matej Kristan, Ales Leonardis, Jiri Matas, Mi...  2017
# 1209719  [Pengfei Zhu, Longyin Wen, Dawei Du, Xiao Bian...  2018
# 1211050  [Matej Kristan, Ales Leonardis, Jiri Matas, Mi...  2018
# 1213086  [Matej Kristan, Ales Leonardis, Jiri Matas, Mi...  2016
# 2625699  [Fausto Acernese, P. Amico, M. Al-Shourbagy, S...  2006
# 3032755  [Mark G. Aartsen, Rasha U. Abbasi, Markus Acke...  2015
# 3264918  [The Fantom Consortium, RIKEN PMII, RIKEN CLST...  2014
# 3367833  [Conrad L. Schoch, Barbara Robbertse, Vincent ...  2014
# 3512319  [Damian Smedley, Syed Haider, Steffen Durinck,...  2015
# 4202317  [Rami Al-Rfou', Guillaume Alain, Amjad Almahai...  2016
# 4255557  [Kim Albertsson, Piero Altoe, Dustin Anderson,...  2018
# 4268065  [Mark G. Aartsen, Rasha U. Abbasi, Markus Acke...  2013
#
#                   type  num_of_authors
# 210012   inproceedings             115
# 538488   inproceedings             102
# 1137966  inproceedings             104
# 1209719  inproceedings             105
# 1211050  inproceedings             155
# 1213086  inproceedings             139
# 2625699        article             119
# 3032755        article             287
# 3264918        article             264
# 3367833        article             101
# 3512319        article             105
# 4202317        article             112
# 4255557        article             118
# 4268065        article             287

# %%
ax = num_of_authors_by_size.plot.bar(figsize=(25, 10))
ax.set_title("Number of Authors of Articls\nfrom 1936 until 2020")
ax.set_xlabel("Number of Authors")
ax.set_ylabel("Number of Articles")
ax.grid()

# %%
ax = num_of_authors_by_size.plot.bar(figsize=(25, 10))
ax.set_title("Number of Authors of Articls\nfrom 1936 until 2020")
ax.set_xlabel("Number of Authors")
ax.set_ylabel("Number of Articles")
ax.set_yscale("log")
ax.grid()

# %%
num_of_authors_by_size[num_of_authors_by_size >= 100]
# Out:
# num_of_authors
# 1      714996
# 2     1276772
# 3     1177290
# 4      746326
# 5      377497
# 6      179682
# 7       78180
# 8       39368
# 9       20579
# 10      12040
# 11       6866
# 12       4403
# 13       2971
# 14       2009
# 15       1428
# 16        993
# 17        787
# 18        615
# 19        499
# 20        406
# 21        321
# 22        242
# 23        199
# 24        181
# 25        151
# 26        101
# 27        110
# 28        112
# dtype: int64

# %%
ax = num_of_authors_by_size[num_of_authors_by_size > 10000].plot.bar(figsize=(15, 10))
ax.set_title("Number of Authors of Articls\nfrom 1936 until 2020\n(Only Values >= 10000)")
ax.set_xlabel("Number of Authors")
ax.set_ylabel("Number of Articles")
ax.grid()

# %% [markdown]
# ## Number of Authors over the Years

# %%
by_year_number_of_authors = df.groupby(["year", "num_of_authors"]).size()
by_year_number_of_authors
# Out:
# year  num_of_authors
# 1936  1                 12
# 1937  1                 14
# 1938  1                  9
#       2                  1
# 1939  1                 18
#                         ..
# 2020  8                 29
#       9                  9
#       10                 4
#       11                 3
#       16                 1
# Length: 1493, dtype: int64

# %%
ax = by_year_number_of_authors[by_year_number_of_authors > 1000].unstack("num_of_authors").plot(figsize=(16, 9))
ax.set_title("Number of Authors of Articls per Year\n(Only Values >= 10000)")
ax.set_xlabel("Year")
ax.set_ylabel("Number of Articles")
ax.grid()
ax.legend(title="Number of Authors")

# %%
by_year_number_of_authors[by_year_number_of_authors > 10000]
# Out:
# year  num_of_authors
# 1991  1                 10180
# 1992  1                 10786
#       2                 10748
# 1993  1                 12081
#       2                 13732
#                         ...
# 2019  2                 58512
#       3                 72352
#       4                 59225
#       5                 38458
#       6                 22224
# Length: 118, dtype: int64

# %%
by_year_number_of_authors.unstack("num_of_authors")
# Out:
# num_of_authors      1        2        3        4        5        6       7    \
# year
# 1936               12.0      NaN      NaN      NaN      NaN      NaN     NaN
# 1937               14.0      NaN      NaN      NaN      NaN      NaN     NaN
# 1938                9.0      1.0      NaN      NaN      NaN      NaN     NaN
# 1939               18.0      NaN      NaN      NaN      NaN      NaN     NaN
# 1940                8.0      2.0      NaN      NaN      NaN      NaN     NaN
# ...                 ...      ...      ...      ...      ...      ...     ...
# 2016            26185.0  66238.0  76604.0  57089.0  32104.0  15679.0  6809.0
# 2017            26132.0  68123.0  80173.0  61961.0  36105.0  18210.0  7907.0
# 2018            25906.0  70339.0  85260.0  67819.0  41699.0  22403.0  9937.0
# 2019            21237.0  58512.0  72352.0  59225.0  38458.0  22224.0  9874.0
# 2020              161.0    513.0    639.0    467.0    299.0    148.0    66.0
#
# num_of_authors     8       9       10   ...  104  105  112  115  118  119  \
# year                                    ...
# 1936               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1937               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1938               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1939               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1940               NaN     NaN     NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# ...                ...     ...     ...  ...  ...  ...  ...  ...  ...  ...
# 2016            3380.0  1733.0   965.0  ...  NaN  NaN  1.0  NaN  NaN  NaN
# 2017            4027.0  1959.0  1179.0  ...  1.0  NaN  NaN  NaN  NaN  NaN
# 2018            4976.0  2568.0  1440.0  ...  NaN  1.0  NaN  NaN  1.0  NaN
# 2019            4939.0  2619.0  1460.0  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 2020              29.0     9.0     4.0  ...  NaN  NaN  NaN  NaN  NaN  NaN
#
# num_of_authors  139  155  264  287
# year
# 1936            NaN  NaN  NaN  NaN
# 1937            NaN  NaN  NaN  NaN
# 1938            NaN  NaN  NaN  NaN
# 1939            NaN  NaN  NaN  NaN
# 1940            NaN  NaN  NaN  NaN
# ...             ...  ...  ...  ...
# 2016            1.0  NaN  NaN  NaN
# 2017            NaN  NaN  NaN  NaN
# 2018            NaN  1.0  NaN  NaN
# 2019            NaN  NaN  NaN  NaN
# 2020            NaN  NaN  NaN  NaN
#
# [85 rows x 95 columns]

# %%
by_year_number_of_authors_percentage = by_year_number_of_authors.groupby("year").apply(lambda x: 100 * x / x.sum())
by_year_number_of_authors_percentage[by_year_number_of_authors_percentage > 0.5]
# Out:
# year  num_of_authors
# 1936  1                 100.000000
# 1937  1                 100.000000
# 1938  1                  90.000000
#       2                  10.000000
# 1939  1                 100.000000
#                            ...
# 2020  4                  19.965797
#       5                  12.783241
#       6                   6.327490
#       7                   2.821719
#       8                   1.239846
# Length: 435, dtype: float64

# %%
ax = by_year_number_of_authors_percentage[by_year_number_of_authors_percentage > 0.5].unstack("num_of_authors").plot(figsize=(16, 9))
ax.set_title("Distribution of Number of Authors of Articls per Year\n(Only Values >= 0.5%)")
ax.set_xlabel("Year")
ax.set_ylabel("Percentage of All Articles of Year")
ax.grid()
ax.legend(title="Number of Authors")

# %% [markdown]
# ## By Author

# %%
# tmp = df[:1000]
# res = pd.DataFrame(tmp["authors"].tolist(), index=tmp["title"]).stack().reset_index(level=1, drop=True).reset_index(name="authors").rename(columns={"authors": "author"})
# res = res.set_index("title").join(tmp.set_index("title")).reset_index()
# res

# %%
by_each_author = pd.DataFrame(df["authors"].tolist(), index=df["title"]).stack().reset_index(level=1, drop=True).reset_index(name="authors").rename(columns={"authors": "author"})
by_each_author = by_each_author.set_index("title").join(df.set_index("title")).reset_index()
by_each_author
# Out:
#                                                       title  \
# 0          Design Principles for Supporting Rigorous Sea...
# 1          Design Principles for Supporting Rigorous Sea...
# 2          Design Principles for Supporting Rigorous Sea...
# 3          Design Principles for Supporting Rigorous Sea...
# 4          Fundamentals for a New Methodology for Induct...
# ...                                                     ...
# 83714766                                                  𝕃
# 83714767                                                  𝕃
# 83714768  👍 as social support: Relational closeness, aut...
# 83714769  👍 as social support: Relational closeness, aut...
# 83714770  👍 as social support: Relational closeness, aut...
#
#                        author  \
# 0         Thorsten Schoormann
# 1              Dennis Behrens
# 2            Michael Fellmann
# 3             Ralf Knackstedt
# 4                Marta Franov
# ...                       ...
# 83714766    Nezar M. Alyazidi
# 83714767     Magdi S. Mahmoud
# 83714768        Caleb T. Carr
# 83714769  Donghee Yvette Wohn
# 83714770     Rebecca A. Hayes
#
#                                                     authors  year  \
# 0         [Thorsten Schoormann, Dennis Behrens, Michael ...  2018
# 1         [Thorsten Schoormann, Dennis Behrens, Michael ...  2018
# 2         [Thorsten Schoormann, Dennis Behrens, Michael ...  2018
# 3         [Thorsten Schoormann, Dennis Behrens, Michael ...  2018
# 4                                            [Marta Franov]  1988
# ...                                                     ...   ...
# 83714766              [Nezar M. Alyazidi, Magdi S. Mahmoud]  2018
# 83714767              [Nezar M. Alyazidi, Magdi S. Mahmoud]  2018
# 83714768  [Caleb T. Carr, Donghee Yvette Wohn, Rebecca A...  2016
# 83714769  [Caleb T. Carr, Donghee Yvette Wohn, Rebecca A...  2016
# 83714770  [Caleb T. Carr, Donghee Yvette Wohn, Rebecca A...  2016
#
#                    type  num_of_authors
# 0         inproceedings               4
# 1         inproceedings               4
# 2         inproceedings               4
# 3         inproceedings               4
# 4         inproceedings               1
# ...                 ...             ...
# 83714766        article               2
# 83714767        article               2
# 83714768        article               3
# 83714769        article               3
# 83714770        article               3
#
# [83714771 rows x 6 columns]

# %%
by_each_author_year = by_each_author.groupby(["author", "year"]).size()
by_each_author_year
# Out:
# author                      year
# "Johann" Sebastian Rudolph  2019    1
# 'Anau Mesui                 2019    1
# 'Maseka Lesaoana            2001    1
#                             2015    1
# 'Niran Adetoro              2012    1
#                                    ..
# xJoachim Luekeny            2018    1
# yoan Lamour                 2019    1
# yurong Long                 2019    1
# zefrank                     2005    2
# zongqi Cai                  2019    1
# Length: 7523074, dtype: int64

# %%
ax = by_each_author_year[by_each_author_year> 10000].unstack("author").sort_index().plot(figsize=(16, 9))
ax.set_title("Distribution of Number of Articls of Authors per Year\n(Only Values >= 10000)")
ax.set_xlabel("Year")
ax.set_ylabel("PArticles per Year")
ax.grid()
ax.legend(title="Author")

# %%
by_each_author_year[by_each_author_year> 10000].unstack("author").sort_index()
# Out:
# author  Daniel Thalmann  David E. Avison        G  Grzegorz Rozenberg  \
# year
# 1994                NaN              NaN      NaN                 NaN
# 1995                NaN              NaN      NaN                 NaN
# 1996                NaN              NaN      NaN                 NaN
# 1997                NaN              NaN      NaN                 NaN
# 1998                NaN              NaN      NaN                 NaN
# 1999                NaN              NaN      NaN                 NaN
# 2000                NaN              NaN      NaN                 NaN
# 2001                NaN              NaN      NaN                 NaN
# 2002            10076.0              NaN      NaN                 NaN
# 2003                NaN              NaN      NaN                 NaN
# 2004            12390.0          11339.0      NaN                 NaN
# 2005            12540.0          11444.0      NaN                 NaN
# 2006            10165.0              NaN      NaN             10138.0
# 2007            12587.0          11498.0      NaN                 NaN
# 2008            14583.0          13317.0  10344.0             10538.0
# 2009            13105.0          11910.0  10092.0             10046.0
# 2010            12528.0          11390.0      NaN                 NaN
# 2011            10391.0              NaN      NaN                 NaN
# 2012            11066.0          10039.0      NaN                 NaN
# 2013            10360.0              NaN      NaN                 NaN
# 2014            12075.0          11028.0      NaN                 NaN
# 2015            10997.0          10037.0      NaN                 NaN
# 2016            10010.0              NaN      NaN                 NaN
# 2017                NaN              NaN      NaN                 NaN
# 2018                NaN              NaN      NaN                 NaN
# 2019                NaN              NaN      NaN                 NaN
#
# author  Guy Fitzgerald        J      Jos  Juan Carlos Augusto  N. K. Bose  \
# year
# 1994               NaN      NaN      NaN                  NaN         NaN
# 1995               NaN      NaN      NaN                  NaN         NaN
# 1996               NaN      NaN      NaN                  NaN         NaN
# 1997               NaN      NaN      NaN                  NaN         NaN
# 1998               NaN      NaN      NaN                  NaN         NaN
# 1999               NaN      NaN      NaN                  NaN         NaN
# 2000               NaN  11683.0      NaN                  NaN     10308.0
# 2001               NaN  12383.0  10670.0                  NaN     10375.0
# 2002               NaN  13791.0  11895.0                  NaN     11395.0
# 2003               NaN  14868.0  12898.0                  NaN     11138.0
# 2004           11558.0  18099.0  15606.0                  NaN     13955.0
# 2005           11668.0  19460.0  17887.0              10002.0     14087.0
# 2006               NaN  18215.0  17462.0              11275.0     11344.0
# 2007           11713.0  20075.0  18376.0              10415.0     14152.0
# 2008           13571.0  22582.0  20647.0              12464.0     16392.0
# 2009           12139.0  21323.0  20381.0              11703.0     14666.0
# 2010           11609.0  20327.0  19075.0              10297.0     14023.0
# 2011               NaN  18490.0  18045.0              10527.0     11591.0
# 2012           10233.0  19160.0  18438.0              10449.0     12355.0
# 2013               NaN  17699.0  16848.0                  NaN     11591.0
# 2014           11239.0  19054.0  17632.0                  NaN     13573.0
# 2015           10229.0  17537.0  16575.0                  NaN     12357.0
# 2016               NaN  16812.0  16360.0                  NaN     11205.0
# 2017               NaN  14662.0  14575.0                  NaN         NaN
# 2018               NaN  13590.0  13479.0                  NaN         NaN
# 2019               NaN      NaN      NaN                  NaN         NaN
#
# author  Nadia Magnenat-Thalmann  Nick Rushby  Philip Hills  T. D. Wilson 0001  \
# year
# 1994                        NaN          NaN           NaN                NaN
# 1995                        NaN          NaN           NaN                NaN
# 1996                        NaN          NaN           NaN                NaN
# 1997                        NaN          NaN           NaN                NaN
# 1998                        NaN          NaN           NaN                NaN
# 1999                    10701.0          NaN           NaN                NaN
# 2000                    13977.0          NaN           NaN            11117.0
# 2001                    14728.0          NaN           NaN            11192.0
# 2002                    16570.0          NaN           NaN            12298.0
# 2003                    16839.0          NaN           NaN            12029.0
# 2004                    20951.0      10905.0       11990.0            15054.0
# 2005                    22644.0      11006.0       12100.0            15201.0
# 2006                    20480.0          NaN           NaN            12231.0
# 2007                    23013.0      11053.0       12156.0            15254.0
# 2008                    26920.0      12811.0       14080.0            17689.0
# 2009                    24472.0      11458.0       12597.0            15821.0
# 2010                    22771.0      10956.0       12045.0            15128.0
# 2011                    20222.0          NaN           NaN            12504.0
# 2012                    21028.0          NaN       10615.0            13332.0
# 2013                    19151.0          NaN           NaN            12492.0
# 2014                    21085.0      10605.0       11660.0            14645.0
# 2015                    19106.0          NaN       10615.0            13332.0
# 2016                    18297.0          NaN           NaN            12088.0
# 2017                    15469.0          NaN           NaN            10023.0
# 2018                    14048.0          NaN           NaN                NaN
# 2019                        NaN          NaN           NaN                NaN
#
# author  Tom Stewart  Vishwani D. Agrawal
# year
# 1994            NaN              10489.0
# 1995            NaN              10894.0
# 1996            NaN              11675.0
# 1997            NaN              11802.0
# 1998            NaN              13380.0
# 1999            NaN              15595.0
# 2000        12075.0              21103.0
# 2001        12150.0              21226.0
# 2002        13352.0              23324.0
# 2003        13050.0              22800.0
# 2004        16350.0              28563.0
# 2005        16501.0              28831.0
# 2006        13275.0              23192.0
# 2007        16577.0              28962.0
# 2008        19203.0              33543.0
# 2009        17178.0              30009.0
# 2010        16427.0              28694.0
# 2011        13575.0              23719.0
# 2012        14478.0              25296.0
# 2013        13580.0              23723.0
# 2014        15901.0              27780.0
# 2015        14477.0              25294.0
# 2016        13126.0              22928.0
# 2017        10876.0              18997.0
# 2018            NaN              16900.0
# 2019            NaN              11401.0
